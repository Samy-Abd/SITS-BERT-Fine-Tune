# %%
#!/usr/bin/env python
# ============================================================
#  SITS-BERT  ·  California-Labeled  ·  6-band data prep
# ------------------------------------------------------------
#  Reads  : /kaggle/input/california-labeled/{Train,Validate,Test}.csv
#  Writes : /kaggle/working/data/6_features_{Train,Validate,Test}.csv
# ------------------------------------------------------------
#  Each output row = 24 × 7 floats  (B1-6 + DOY)  +  label
# ============================================================

import csv, subprocess, sys, shutil, random
from pathlib import Path
import numpy as np

# %%
# ───────────────────────────────────
# 0 · CONFIG
# ───────────────────────────────────
SEED       = 42
SRC_DIR    = Path("/kaggle/input/california-labeled")
DST_DIR    = Path("/kaggle/working/data")
SITS_REPO  = Path("/kaggle/working/SITS-BERT")
T_KEEP     = 24                       # timesteps to keep / pad
FEATS_KEEP = [0, 1, 2, 3, 4, 5, 10]   # 6 bands + DOY   (drop 10 to remove DOY)
F_SOURCE   = 11                       # 10 spectral bands + DOY in original rows

# %%
# ───────────────────────────────────
# 1 · ENVIRONMENT
# ───────────────────────────────────
def _sh(cmd: str) -> None:
    print(f"[shell] {cmd}")
    subprocess.check_call(cmd, shell=True)

def ensure_env() -> None:
    """Install lightweight deps & clone SITS-BERT once."""
    if not shutil.which("pandas"):
        _sh("pip install -q pandas numpy")
    if not SITS_REPO.exists():
        _sh(f"git clone -q https://github.com/linlei1214/SITS-BERT.git {SITS_REPO}")
    sys.path.append(str(SITS_REPO))

# %%
# ───────────────────────────────────
# 2 · ROW SLICE HELPER
# ───────────────────────────────────
def slice_row(row: list[str]) -> list[str] | None:
    """
    Return a flattened row: 24×selected-features + label.
    Skip malformed rows (those whose length-1 isn't divisible by 11).
    
    Input format: [spectral_data..., class_label]  # Class is LAST column
    Output format: [band1_t1, band1_t2, ..., band1_t24, band2_t1, ..., DOY_t24, class]
    """
    label = row[-1]  # Class label is in the LAST column
    floats = row[:-1]  # Everything except the last column (all spectral data)
    
    if (len(floats) % F_SOURCE) != 0:
        return None                               # corrupt → skip
    
    T_full = len(floats) // F_SOURCE              # actual steps (41–45)
    
    # --- pad if shorter than 24 (very rare) -----
    if T_full < T_KEEP:
        # Need to pad each band separately
        padded_floats = []
        for band_idx in range(F_SOURCE):
            band_start = band_idx * T_full
            band_data = floats[band_start:band_start + T_full]
            # Pad this band to T_KEEP length
            band_data.extend(['0'] * (T_KEEP - T_full))
            padded_floats.extend(band_data)
        floats = padded_floats
        T_full = T_KEEP
    
    # -------- build the output (features … label) --------
    out = []
    for f in FEATS_KEEP:                          # each wanted feature (band)
        band_start = f * T_full                   # start index of that band
        out.extend(floats[band_start : band_start + T_KEEP])  # first 24 values of this band
    
    out.append(label)
    return out

# %%
# ───────────────────────────────────
# 3 · PROCESS ONE SPLIT
# ───────────────────────────────────
def process_split(split: str) -> None:
    src = SRC_DIR / f"{split}.csv"
    dst = DST_DIR / f"6_features_{split}.csv"
    kept = skipped = 0
    
    with src.open() as fin, dst.open("w", newline="") as fout:
        reader, writer = csv.reader(fin), csv.writer(fout)
        for row in reader:
            new_row = slice_row(row)
            if new_row is None:
                skipped += 1
            else:
                writer.writerow(new_row)
                kept += 1
    
    print(f"{split:<8}: wrote {kept:>6} rows   |   skipped {skipped}")

# %%
# ───────────────────────────────────
# 4 · MAIN
# ───────────────────────────────────
def main() -> None:
    random.seed(SEED); np.random.seed(SEED)
    ensure_env()
    DST_DIR.mkdir(parents=True, exist_ok=True)
    
    for split in ["Train", "Validate", "Test"]:
        process_split(split)
    
    print("\n🟢 All done — cleaned files live in /kaggle/working/data/")
    print(f"    Each row = {T_KEEP} × {len(FEATS_KEEP)} floats + label")

# %%
# ───────────────────────────────────
if __name__ == "__main__":
    main()
# Out:
# [shell] pip install -q pandas numpy
# [shell] git clone -q https://github.com/linlei1214/SITS-BERT.git /kaggle/working/SITS-BERT
# Train   : wrote   1300 rows   |   skipped 0
# Validate: wrote   1300 rows   |   skipped 0
# Test    : wrote 318588 rows   |   skipped 0
#
# 🟢 All done — cleaned files live in /kaggle/working/data/
#     Each row = 24 × 7 floats + label

# %%
# !mkdir checkpoints_finetune

# %%
def debug_output_shape():
    import pandas as pd
    df = pd.read_csv('/kaggle/working/data/6_features_Train.csv', header=None)
    sample_row = df.iloc[0].values
    features = sample_row[:-1]  # everything except label
    label = sample_row[-1]
    
    print(f"Output features shape: {len(features)}")
    print(f"Expected: 24 timesteps × 7 features = {24 * 7}")
    print(f"Label: {label}")
    print(f"Features sample: {features[:14]}")  # first 2 timesteps worth

# %%
debug_output_shape()
# Out:
# Output features shape: 168
# Expected: 24 timesteps × 7 features = 168
# Label: 7
# Features sample: [808 647 487 459 446 463 464 518 433 532 537 400 549 518]

# %%
# !sed -i "s#self.pooling = nn.MaxPool1d(64)#self.pooling = nn.MaxPool1d(24)#" /kaggle/working/SITS-BERT/code/model/classification_model.py

# %%
# !python /kaggle/working/SITS-BERT/code/finetuning.py \
  --file_path /kaggle/working/data/6_features_ \
  --pretrain_path '/kaggle/input/doyt2c/transformers/default/1/' \
  --finetune_path /kaggle/working/checkpoints_finetune/ \
  --num_features 6 \
  --max_length 24 \
  --num_classes 13 \
  --epochs 100 \
  --batch_size 128 \
  --hidden_size 256 \
  --layers 3 \
  --attn_heads 8 \
  --learning_rate 2e-4 \
  --dropout 0.1
# Out:
# 2025-06-15 17:13:22.079027: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750007602.265699     101 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750007602.319851     101 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading Data sets...
# training samples: 1300, validation samples: 1300, testing samples: 318588
# Creating Dataloader...
# Initialing SITS-BERT...
# Loading pre-trained model parameters...
# Creating Downstream Task Trainer...
# Fine-tuning SITS-BERT...
# EP0, train_OA=11.92, train_Kappa=0.046, validate_OA=17.00, validate_Kappa=0.101
# EP:0 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP1, train_OA=16.62, train_Kappa=0.097, validate_OA=18.85, validate_Kappa=0.121
# EP:1 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP2, train_OA=18.23, train_Kappa=0.114, validate_OA=20.08, validate_Kappa=0.134
# EP:2 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP3, train_OA=20.54, train_Kappa=0.139, validate_OA=22.46, validate_Kappa=0.160
# EP:3 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP4, train_OA=21.46, train_Kappa=0.149, validate_OA=24.00, validate_Kappa=0.177
# EP:4 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP5, train_OA=22.77, train_Kappa=0.163, validate_OA=23.08, validate_Kappa=0.167
# EP6, train_OA=23.38, train_Kappa=0.170, validate_OA=26.46, validate_Kappa=0.203
# EP:6 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP7, train_OA=25.85, train_Kappa=0.197, validate_OA=24.08, validate_Kappa=0.177
# EP8, train_OA=26.77, train_Kappa=0.207, validate_OA=34.69, validate_Kappa=0.292
# EP:8 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP9, train_OA=31.69, train_Kappa=0.260, validate_OA=31.85, validate_Kappa=0.262
# EP10, train_OA=34.00, train_Kappa=0.285, validate_OA=37.08, validate_Kappa=0.318
# EP:10 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP11, train_OA=39.23, train_Kappa=0.342, validate_OA=47.08, validate_Kappa=0.427
# EP:11 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP12, train_OA=46.08, train_Kappa=0.416, validate_OA=36.38, validate_Kappa=0.311
# EP13, train_OA=45.85, train_Kappa=0.413, validate_OA=49.69, validate_Kappa=0.455
# EP:13 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP14, train_OA=51.15, train_Kappa=0.471, validate_OA=53.92, validate_Kappa=0.501
# EP:14 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP15, train_OA=57.62, train_Kappa=0.541, validate_OA=63.23, validate_Kappa=0.602
# EP:15 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP16, train_OA=58.92, train_Kappa=0.555, validate_OA=63.69, validate_Kappa=0.607
# EP:16 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP17, train_OA=60.38, train_Kappa=0.571, validate_OA=66.54, validate_Kappa=0.637
# EP:17 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP18, train_OA=65.31, train_Kappa=0.624, validate_OA=66.92, validate_Kappa=0.642
# EP:18 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP19, train_OA=65.85, train_Kappa=0.630, validate_OA=64.15, validate_Kappa=0.612
# EP20, train_OA=66.00, train_Kappa=0.632, validate_OA=67.85, validate_Kappa=0.652
# EP:20 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP21, train_OA=68.31, train_Kappa=0.657, validate_OA=68.38, validate_Kappa=0.657
# EP:21 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP22, train_OA=68.77, train_Kappa=0.662, validate_OA=71.77, validate_Kappa=0.694
# EP:22 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP23, train_OA=71.62, train_Kappa=0.693, validate_OA=73.08, validate_Kappa=0.708
# EP:23 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP24, train_OA=72.69, train_Kappa=0.704, validate_OA=72.54, validate_Kappa=0.702
# EP25, train_OA=73.54, train_Kappa=0.713, validate_OA=73.77, validate_Kappa=0.716
# EP:25 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP26, train_OA=73.38, train_Kappa=0.712, validate_OA=74.85, validate_Kappa=0.728
# EP:26 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP27, train_OA=75.38, train_Kappa=0.733, validate_OA=75.62, validate_Kappa=0.736
# EP:27 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP28, train_OA=74.54, train_Kappa=0.724, validate_OA=76.69, validate_Kappa=0.747
# EP:28 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP29, train_OA=75.77, train_Kappa=0.737, validate_OA=75.15, validate_Kappa=0.731
# EP30, train_OA=75.85, train_Kappa=0.738, validate_OA=78.23, validate_Kappa=0.764
# EP:30 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP31, train_OA=77.92, train_Kappa=0.761, validate_OA=78.85, validate_Kappa=0.771
# EP:31 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP32, train_OA=78.15, train_Kappa=0.763, validate_OA=80.00, validate_Kappa=0.783
# EP:32 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP33, train_OA=78.38, train_Kappa=0.766, validate_OA=80.85, validate_Kappa=0.792
# EP:33 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP34, train_OA=79.77, train_Kappa=0.781, validate_OA=79.54, validate_Kappa=0.778
# EP35, train_OA=80.08, train_Kappa=0.784, validate_OA=80.08, validate_Kappa=0.784
# EP36, train_OA=79.77, train_Kappa=0.781, validate_OA=81.69, validate_Kappa=0.802
# EP:36 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP37, train_OA=80.15, train_Kappa=0.785, validate_OA=79.69, validate_Kappa=0.780
# EP38, train_OA=80.69, train_Kappa=0.791, validate_OA=78.85, validate_Kappa=0.771
# EP39, train_OA=79.62, train_Kappa=0.779, validate_OA=80.38, validate_Kappa=0.788
# EP40, train_OA=80.62, train_Kappa=0.790, validate_OA=80.08, validate_Kappa=0.784
# EP41, train_OA=80.54, train_Kappa=0.789, validate_OA=80.69, validate_Kappa=0.791
# EP42, train_OA=81.38, train_Kappa=0.798, validate_OA=80.54, validate_Kappa=0.789
# EP43, train_OA=80.69, train_Kappa=0.791, validate_OA=83.23, validate_Kappa=0.818
# EP:43 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP44, train_OA=82.77, train_Kappa=0.813, validate_OA=80.62, validate_Kappa=0.790
# EP45, train_OA=83.31, train_Kappa=0.819, validate_OA=83.54, validate_Kappa=0.822
# EP:45 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP46, train_OA=82.38, train_Kappa=0.809, validate_OA=82.77, validate_Kappa=0.813
# EP47, train_OA=83.00, train_Kappa=0.816, validate_OA=81.31, validate_Kappa=0.797
# EP48, train_OA=83.08, train_Kappa=0.817, validate_OA=83.15, validate_Kappa=0.818
# EP49, train_OA=84.23, train_Kappa=0.829, validate_OA=83.54, validate_Kappa=0.822
# EP50, train_OA=84.54, train_Kappa=0.833, validate_OA=84.23, validate_Kappa=0.829
# EP:50 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP51, train_OA=85.54, train_Kappa=0.843, validate_OA=83.62, validate_Kappa=0.822
# EP52, train_OA=84.46, train_Kappa=0.832, validate_OA=83.38, validate_Kappa=0.820
# EP53, train_OA=85.31, train_Kappa=0.841, validate_OA=84.69, validate_Kappa=0.834
# EP:53 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP54, train_OA=85.23, train_Kappa=0.840, validate_OA=82.69, validate_Kappa=0.812
# EP55, train_OA=84.00, train_Kappa=0.827, validate_OA=83.69, validate_Kappa=0.823
# EP56, train_OA=82.77, train_Kappa=0.813, validate_OA=81.38, validate_Kappa=0.798
# EP57, train_OA=84.85, train_Kappa=0.836, validate_OA=83.08, validate_Kappa=0.817
# EP58, train_OA=84.92, train_Kappa=0.837, validate_OA=83.54, validate_Kappa=0.822
# EP59, train_OA=84.77, train_Kappa=0.835, validate_OA=83.92, validate_Kappa=0.826
# EP60, train_OA=86.08, train_Kappa=0.849, validate_OA=84.77, validate_Kappa=0.835
# EP:60 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP61, train_OA=85.08, train_Kappa=0.838, validate_OA=85.00, validate_Kappa=0.837
# EP:61 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP62, train_OA=86.00, train_Kappa=0.848, validate_OA=83.69, validate_Kappa=0.823
# EP63, train_OA=86.69, train_Kappa=0.856, validate_OA=85.08, validate_Kappa=0.838
# EP:63 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP64, train_OA=86.08, train_Kappa=0.849, validate_OA=85.08, validate_Kappa=0.838
# EP65, train_OA=86.77, train_Kappa=0.857, validate_OA=85.38, validate_Kappa=0.842
# EP:65 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP66, train_OA=87.38, train_Kappa=0.863, validate_OA=84.54, validate_Kappa=0.833
# EP67, train_OA=86.31, train_Kappa=0.852, validate_OA=82.08, validate_Kappa=0.806
# EP68, train_OA=86.85, train_Kappa=0.857, validate_OA=84.46, validate_Kappa=0.832
# EP69, train_OA=86.46, train_Kappa=0.853, validate_OA=85.00, validate_Kappa=0.837
# EP70, train_OA=86.08, train_Kappa=0.849, validate_OA=85.92, validate_Kappa=0.848
# EP:70 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP71, train_OA=88.08, train_Kappa=0.871, validate_OA=85.54, validate_Kappa=0.843
# EP72, train_OA=88.31, train_Kappa=0.873, validate_OA=85.46, validate_Kappa=0.842
# EP73, train_OA=86.23, train_Kappa=0.851, validate_OA=85.46, validate_Kappa=0.842
# EP74, train_OA=87.15, train_Kappa=0.861, validate_OA=84.62, validate_Kappa=0.833
# EP75, train_OA=87.69, train_Kappa=0.867, validate_OA=86.15, validate_Kappa=0.850
# EP:75 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP76, train_OA=88.00, train_Kappa=0.870, validate_OA=85.85, validate_Kappa=0.847
# EP77, train_OA=88.15, train_Kappa=0.872, validate_OA=85.38, validate_Kappa=0.842
# EP78, train_OA=88.31, train_Kappa=0.873, validate_OA=85.85, validate_Kappa=0.847
# EP79, train_OA=88.69, train_Kappa=0.878, validate_OA=85.08, validate_Kappa=0.838
# EP80, train_OA=89.85, train_Kappa=0.890, validate_OA=86.54, validate_Kappa=0.854
# EP:80 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP81, train_OA=89.92, train_Kappa=0.891, validate_OA=85.08, validate_Kappa=0.838
# EP82, train_OA=89.69, train_Kappa=0.888, validate_OA=86.00, validate_Kappa=0.848
# EP83, train_OA=89.54, train_Kappa=0.887, validate_OA=87.00, validate_Kappa=0.859
# EP:83 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP84, train_OA=89.00, train_Kappa=0.881, validate_OA=86.54, validate_Kappa=0.854
# EP85, train_OA=88.77, train_Kappa=0.878, validate_OA=86.69, validate_Kappa=0.856
# EP86, train_OA=89.54, train_Kappa=0.887, validate_OA=86.31, validate_Kappa=0.852
# EP87, train_OA=90.08, train_Kappa=0.892, validate_OA=86.85, validate_Kappa=0.857
# EP88, train_OA=88.23, train_Kappa=0.872, validate_OA=86.77, validate_Kappa=0.857
# EP89, train_OA=88.46, train_Kappa=0.875, validate_OA=84.92, validate_Kappa=0.837
# EP90, train_OA=89.46, train_Kappa=0.886, validate_OA=86.00, validate_Kappa=0.848
# EP91, train_OA=89.62, train_Kappa=0.887, validate_OA=85.31, validate_Kappa=0.841
# EP92, train_OA=89.85, train_Kappa=0.890, validate_OA=86.08, validate_Kappa=0.849
# EP93, train_OA=91.23, train_Kappa=0.905, validate_OA=87.00, validate_Kappa=0.859
# EP94, train_OA=90.46, train_Kappa=0.897, validate_OA=86.92, validate_Kappa=0.858
# EP95, train_OA=88.54, train_Kappa=0.876, validate_OA=85.15, validate_Kappa=0.839
# EP96, train_OA=88.23, train_Kappa=0.872, validate_OA=85.85, validate_Kappa=0.847
# EP97, train_OA=90.00, train_Kappa=0.892, validate_OA=86.38, validate_Kappa=0.852
# EP98, train_OA=90.54, train_Kappa=0.897, validate_OA=87.54, validate_Kappa=0.865
# EP:98 Model Saved on: /kaggle/working/checkpoints_finetune/checkpoint.tar
# EP99, train_OA=91.23, train_Kappa=0.905, validate_OA=87.00, validate_Kappa=0.859
#
#
#
#
# Testing SITS-BERT...
# EP:98 Model loaded from: /kaggle/working/checkpoints_finetune/checkpoint.tar
# test_OA = 86.57, test_kappa = 0.843, test_AA = 0.873

# %%
ls /kaggle/working/SITS-BERT/code/
# Out:
# dataset/       model/          run_finetuning.sh             run_pretraining.sh
# finetuning.py  pretraining.py  run_finetuning_unpretrain.sh  trainer/

# %%
# %matplotlib inline

import sys, inspect, csv, numpy as np, torch
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# ───────────────────────────── Configuration ──────────────────────────────
ROOT       = Path("/kaggle/working")                       # adjust as needed
CSV_TEST   = ROOT / "data" / "6_features_Test.csv"
CKPT_FILE  = ROOT / "checkpoints_finetune" / "checkpoint.tar"
SITS_REPO  = ROOT / "SITS-BERT" / "code"
BATCH_SIZE = 128
SEQ_LEN    = 24
DEVICE     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ─────────── Add repo to path & import ────────────────────────────────────
sys.path.append(str(SITS_REPO))
from model.classification_model import SBERTClassification
from model.bert                 import SBERT

# ─────────── Build SBERT helper ──────────────────────────────────────────
_sig = inspect.signature(SBERT.__init__)
def make_sbert(num_features: int) -> torch.nn.Module:
    # SBERT.__init__(self, num_features, hidden, n_layers, attn_heads, dropout=0.1)
    base = {
        "num_features": num_features,
        "hidden":       256,
        "n_layers":     3,
        "attn_heads":   8,
        "dropout":      0.1,
    }
    kwargs = {k: v for k, v in base.items() if k in _sig.parameters}
    missing = [
        p.name for p in _sig.parameters.values()
        if p.default is inspect._empty and p.name not in kwargs and p.name != "self"
    ]
    if missing:
        raise RuntimeError(f"❌ Missing SBERT init args: {missing}")
    return SBERT(**kwargs)

# ─────────── Dataset ──────────────────────────────────────────────────────
class SITSCSVDataset(Dataset):
    """
    Parses CSV rows of (SEQ_LEN * n_feat floats) + label,
    where n_feat = 7 (6 spectral bands + DOY).
    The CSV is organized band-by-band, so we reshape then transpose.
    """
    def __init__(self, path: Path, seq_len: int = 24):
        rows   = list(csv.reader(path.open()))
        n_feat = (len(rows[0]) - 1) // seq_len
        spec   = n_feat - 1  # last channel is DOY

        X, D, Y = [], [], []
        for r in rows:
            if not r: 
                continue
            arr = np.asarray(r[:-1], dtype=np.float32)
            if arr.size != seq_len * n_feat:
                continue
            # reshape band-major → time-major
            seq = arr.reshape(n_feat, seq_len).T  # [SEQ_LEN, n_feat]
            X.append(seq[:, :spec])               # [SEQ_LEN, spec]
            D.append(seq[:,  spec].astype(np.int64))  # [SEQ_LEN]
            Y.append(int(r[-1]))

        self.x   = torch.tensor(np.stack(X) / 10000.0, dtype=torch.float32)          # [N, SEQ_LEN, spec]
        self.doy = torch.tensor(np.stack(D))          # [N, SEQ_LEN]
        self.y   = torch.tensor(Y, dtype=torch.long)  # [N]
        print(f"✅ Loaded {len(self):,} samples "
              f"({spec}-band + DOY × {seq_len}, {int(self.y.max()+1)} classes)")

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.x[idx], self.doy[idx], self.y[idx]

# ─────────── Evaluation ───────────────────────────────────────────────────
# 1) Load data
ds     = SITSCSVDataset(CSV_TEST, SEQ_LEN)
loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False)

# 2) Build model & send to device
sbert = make_sbert(ds.x.size(-1))
model = SBERTClassification(sbert, int(ds.y.max()+1)).to(DEVICE)

# 3) Strictly load checkpoint
ckpt = torch.load(CKPT_FILE, map_location=DEVICE)
res  = model.load_state_dict(ckpt["model_state_dict"], strict=True)
print("✅ Checkpoint loaded:", CKPT_FILE)
if res.missing_keys:
    print("⚠️ Missing keys:", res.missing_keys)
if res.unexpected_keys:
    print("⚠️ Unexpected keys:", res.unexpected_keys)

model.eval()

# 4) Get positional-embedding size & clamp DOY
pe      = model.sbert.embedding.position.pe
pe_size = pe.size(0)

# 5) Inference
y_true, y_pred = [], []
with torch.no_grad():
    for xb, doy, yb in loader:
        xb  = xb.to(DEVICE)
        doy = torch.clamp(doy.to(DEVICE).long() - 1, 0, pe_size - 1)
        mask = torch.ones(xb.size(0), SEQ_LEN, dtype=torch.bool, device=DEVICE)

        logits = model(xb, doy, mask)
        preds  = logits.argmax(dim=1).cpu().tolist()
        y_pred.extend(preds); y_true.extend(yb.tolist())

# 6) Classification report (no warnings)
print("\n" + classification_report(
    y_true, y_pred, digits=4, zero_division=0
))

# 7) Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
try:
    import seaborn as sns
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
except ImportError:
    plt.imshow(cm, interpolation="nearest", aspect="auto")
plt.title("SITS-BERT Confusion Matrix")
plt.xlabel("Predicted"); plt.ylabel("True")
plt.tight_layout()
plt.show()
# Out:
# ✅ Loaded 318,588 samples (6-band + DOY × 24, 13 classes)
# ✅ Checkpoint loaded: /kaggle/working/checkpoints_finetune/checkpoint.tar
#
#               precision    recall  f1-score   support
#
#            0     0.9201    0.9298    0.9249      3804
#            1     0.9259    0.9356    0.9308     24301
#            2     0.2934    0.9619    0.4497      2180
#            3     0.8865    0.9510    0.9176     14623
#            4     0.8413    0.9067    0.8728     13192
#            5     0.9498    0.7668    0.8486     66592
#            6     0.7427    0.8623    0.7980     11741
#            7     0.9256    0.8553    0.8891     53761
#            8     0.5806    0.7899    0.6693     14352
#            9     0.2614    0.6303    0.3695      1666
#           10     0.8675    0.9879    0.9238      2968
#           11     0.9772    0.9339    0.9551     74918
#           12     0.7583    0.8256    0.7905     34490
#
#     accuracy                         0.8637    318588
#    macro avg     0.7639    0.8721    0.7954    318588
# weighted avg     0.8888    0.8637    0.8710    318588
